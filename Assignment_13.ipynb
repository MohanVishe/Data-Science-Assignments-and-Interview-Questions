# %% [markdown]
# ###   <font color='red'>1. Explain what inheritance is in object-oriented programming and why it is used.</font>

# %%
"""INHERITANCE""":
# 1. Tt is fundamental concept in Object Oriented Programming which allows a class
#   (called as sub class or derived class) to inherit properties and behaviors from
#    another class (called as superclass or base class )

# 2. Subclass inherits from superclass its attributes and methods.
# 3. Subclass called as speciallized version of superclass
# 4. child class(subclass) can then extend or modify the behavior of the parent class
#    (superclass) by adding new features or overriding existing ones.

# %%
"USES":
# 1. Code Reusability : Inherited properties and methods from superclass used in multiple subclass
#    reduce code duplication and makihng maintenance easy.

# 2. Hierarchical Organization : Inheritance organizes  classes hierarchial manner
#    Making easier to understand the code structure  and nevigate

# 3. Polymorphism: Inheritance enables polymorphism, allowing different subclass
#    to be treated interchangeably through a shared superclass interface,
#    promoting flexibility in code design.

# 4.Extensibility: By using inheritance, you can add new functionalities and
#   attributes to the child classes without modifying the parent class.

# %% [markdown]
# ###   <font color='red'>2. Discuss the concept of single inheritance and multiple inheritance, highlighting their differences and advantages.</font>

# %%
#  Inheritance can be categorized into two main types:
#   1. single inheritance 2. multiple inheritance.

"""Single Inheritance""":

# 1. Single inheritance refers to the concept
#    where a class can inherit from only one parent class.
# 2. Child class can have only one direct ancestor
# 3. This is most common type of inheritance suppeorted by python and various languages

"""Advantages """

# 1. Simplicity : straightforward hierarchy and easy to understand
#                 code more manageable and less prone to ambiguity

# 2.Avioding Diamond Problem : The Diamond Problem occurs when
#            a class inherits from two classes that share a common ancestor,
#            resulting in potential conflicts when accessing shared attributes or methods.

# 3.Encourages Composition over Inheritance: With single inheritance,
#      developers are more likely to use composition, a design principle where
#      classes are composed of other objects, rather than relying on a
#      complex hierarchy of inheritance.

# %%
"""Multiple Inheritance"""
# Multiple inheritance refers to a class inheriting from multiple superclasses.
# subclass can have multiple direct parent classes from which it inherits properties and methods.
# It is powerfull but complex to manage and not support all languages(e.g.,Java)

"""Advantages"""
# Code Reusability :Allow inherit functionalities from multiple sources.
#      able to  code reuse and reduce redundant code

# useful for modeling complex relationships between classes,where a subclass
#  exhibits characteristics from multiple unrelated classes.

# %%
"""Difference """:
# number of parent class : single inhertance = 1
#                          multiple inhertance > 1

# Ambiguity : single inheritance :avoids
#              multiple inheritance :Diamond problem

# %% [markdown]
# ###   <font color='red'>3. Explain the terms "base class" and "derived class" in the context of inheritance.</font>

# %%
# "base class" and "derived class"  describe the relationship between classes
# Inheritance allows  class to inherit properties from class,creat hierarchical relationship


"""Base Class / superclass / Parent class""":
# class from which another class inherits properties and behaviors.
# class encapsulates the general characteristics that multiple subclasses may share.

# %%
"""Child class/ Super class/Parent class""":
# class that inherits properties and behaviors from a base class
# Extend the functionality of the base class by adding new attributes or methods or by overriding the existing ones.
# The derived class specializes the behavior of the base class to represent a more specific or specialized type.

# %%
# Parent Class

class animal :
  def __init__(self,name):
    self.name=name
  def info(self):
    print(f"The name of this animal is {self.name}")

# Child  class
class dog (animal) :
  def __init__(self,name,colour):
    self.name=name
    self.colour=colour
  def information(self):
    super().info()
    print(f"This is a dog having colour : {self.colour}")

# %% [markdown]
# ###   <font color='red'>4. What is the significance of the "protected" access modifier in inheritance? How does it differ from "private" and "public" modifiers?</font>

# %%
#In Python, there are no strict access modifiers like "protected" or "private"
#         as found in some other programming languages (e.g., C++ or Java).
# However, there is a convention for indicating protected
#         and private attributes using single or double underscores as prefixes.

# %%
# The "protected" access modifier in crucial keyword used to control visibility and accessibility of class members.
#  allows access within the class, its subclasses, and other classes within the same package,
#  striking a balance between "public" and "private" modifiers.
#  It enhances encapsulation by restricting access outside the class hierarchy.
# By using "protected," developers can build robust and organized class hierarchies,
#  maximizing the benefits of inheritance and object-oriented principles.

# %% [markdown]
# https://www.linkedin.com/feed/update/urn:li:activity:7087299419410198528?utm_source=share&utm_medium=member_desktop
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###   <font color='red'>5. What is the purpose of the "super" keyword in inheritance? Provide an example.</font>

# %%
# The "super" keyword is used to refer to the superclass from within a subclass.
# Allows the subclass to access and invoke the members defined in its superclass.
# when the subclass wants to extend or override the functionality of the superclass
#            while still maintaining access to its original behavior.

# %%
# Parent Class

class animal :
  def __init__(self,name):
    self.name=name
  def info(self):
    print(f"The name of this animal is {self.name}")

# Child  class
class dog (animal) :
  def __init__(self,name,colour):
    super().__init__()
    self.colour=colour
  def information(self):
    super().info()
    print(f"This is a dog having colour : {self.colour}")

# %%
# Using super ensures that the inheritance hierarchy is respected
#      and the methods of each class are called in the correct order.
#      This way, you can build upon the functionality of the parent class in a more organized and maintainable manner.

# %% [markdown]
# ###   <font color='red'>6. Create a base class called "Vehicle" with attributes like "make", "model", and "year".Then, create a derived class called "Car" that inherits from "Vehicle" and adds an attribute called "fuel_type". Implement appropriate methods in both classes.</font>

# %%
class Vehicle :
  def __init__(self,make,model,year):
    self.make=make
    self.model=model
    self.year=year

  def description(self):
    print(f"""    make : {self.make}
    model: {self.model}
    year : {self.year}""")

class Car(Vehicle):
  def __init__(self,make,model,year,fuel_type):
    super().__init__(make,model,year)
    self.fuel_type=fuel_type

  def description(self):
    print("The is a CAr")
    super().description()
    print(f"The fuel type of car is {self.fuel_type}")

# %%
BMW= Car("abc","pqr","yyyy","xyz")

# %%
BMW.description()
# Out:
# The is a CAr
#     make : abc
#     model: pqr
#     year : yyyy
# The fuel type of car is xyz

# %% [markdown]
# ###   <font color='red'>7. Create a base class called "Employee" with attributes like "name" and "salary." Derive two classes, "Manager" and "Developer," from "Employee." Add an additional attribute called "department" for the "Manager" class and "programming_language" for the "Developer" class.</font>

# %%
class Employee:
  def __init__(self,name,salary):
    self.name=name
    self.salary=salary

  def info(self):
    print(f"The Employee {self.name} has salary {self.salary}")

class Manager(Employee):
  def __init__(self,name,salary,department):
    super().__init__(name,salary)
    self.department=department

  def detail(self):
    super().info()
    print(f"The Manager is in department {self.department}")

class Developer(Employee):
  def __init__(self,name,salary,programming_language):
    super().__init__(name,salary)
    self.programming_language=programming_language

  def detail(self):
    super().info()
    print(f"The employee develop on programming language {self.programming_language}")

# %%
a=Developer("abc",10000,"pqr")
a.detail()
# Out:
# The Employee abc has salary 10000
# The employee develop on programming language pqr

# %%
a=Manager("abc",10000,"sales")
a.detail()
# Out:
# The Employee abc has salary 10000
# The Manager is in department sales

# %% [markdown]
# ###   <font color='red'>8. Design a base class called "Shape" with attributes like "colour" and "border_width." Create derived classes, "Rectangle" and "Circle," that inherit from "Shape" and add specific attributes like "length" and "width" for the "Rectangle" class and "radius" for the "Circle" class.</font>

# %%
class Shape:
  def __init__(self,colour,border_width):
    self.colour=colour
    self.border_width=border_width

class Rectangle(Shape):
  def __init__(self,colour,border_width,length,width):
    super().__init__(colour,border_width)
    self.length=length
    self.width=width

  def area (self):
    return self.length * self.width

class Circle (Shape):
  def __init__(self,colour,border_width,radius):
    super().__init__(colour,border_width)
    self.radius=radius

  def area(self):
    return 3.14*(self.radius)**2

# %%
rec=Rectangle("abc",4,5,6)
rec.area()
# Out:
# 30

# %%
cir=Circle("pqr",5,10)
cir.area()
# Out:
# 314.0

# %% [markdown]
# ###   <font color='red'>9. Create a base class called "Device" with attributes like "brand" and "model." Derive two classes, "Phone" and "Tablet," from "Device." Add specific attributes like "screen_size" for the "Phone" class and "battery_capacity" for the "Tablet" class.</font>

# %%
class Device:
  def __init__(self,brand,model):
    self.brand=brand
    self.model=model
  def info (self):
    print(f"Brand name={self.brand} ,model name={self.model}")

class Phone(Device):
  def __init__(self,brand,model,screen_size):
    super().__init__(brand,model)
    self.screen_size=screen_size
  def info (self):
    print(f"This is phone with brand name= {self.brand},model name={self.model} and screen_size={self.screen_size}")

class Tablet(Device):
  def __init__(self,brand,model,battery_capacity):
    super().__init__(brand,model)
    self.battery_capacity=battery_capacity

  def info (self):
    print(f"This is Tablet with brand name={self.brand},model name={self.model} and screen_size={self.battery_capacity}")

# %%
a=Device("abc","zz-22")
b=Phone("pqr","yy-11",7)
c=Tablet("lmn","xx-00",4000)

# %%
a.info()
b.info()
c.info()
# Out:
# Brand name=abc ,model name=zz-22
# This is phone with brand name= pqr,model name=yy-11 and screen_size=7
# This is Tablet with brand name=lmn,model name=xx-00 and screen_size=4000

# %% [markdown]
# ###   <font color='red'>10. Create a base class called "BankAccount" with attributes like "account_number" and "balance." Derive two classes, "SavingsAccount" and "CheckingAccount," from "BankAccount." Add specific methods like "calculate_interest" for the "SavingsAccount" class and "deduct_fees" for the "CheckingAccount" class.</font>

# %%
class BankAccount:
  def __init__(self,account_number,balance):
    self.account_number=account_number
    self.balance=balance
  def deposite(self,amount):
    self.balance=self.balance+amount

  def withdraw(self,amount):
    if self.balance < amount:
      print("Insufficient balance")
    else:
      self.balance=self.balance-amount
  def show_balance(self):
    print(self.balance)


class SavingAccount(BankAccount):
  def calculate_interest(self,interest_rate):
    self.balance=self.balance +(self.balance*interest_rate)/100
    print("INTEREST ADDED :",self.balance*interest_rate/100)

class CheckingAccount(BankAccount):
  def deduct_fees(self,fee):
    if fee < self.balance:
      self.balance=self.balance-fee
      return "We deduct_fees"

    else :
      return "We cant deduct_fees"

# %%
a=BankAccount("BBB",1000)
b=SavingAccount("SSS",2000)
c=CheckingAccount("CCC",500)

# %%
a.show_balance()
a.deposite(500)
a.withdraw(1000)
a.show_balance()
# Out:
# 1000
# 500

# %%
b.show_balance()
b.deposite(500)
b.withdraw(1000)
b.show_balance()
# Out:
# 2000
# 1500

# %%
b.calculate_interest(5)
# Out:
# INTEREST ADDED : 78.75

# %%
c.show_balance()
c.deposite(100)
c.withdraw(1000)
c.show_balance()
# Out:
# 500
# Insufficient balance
# 600

# %%
c.deduct_fees(100)
# Out:
# 'We deduct_fees'

# %%
c.show_balance()
# Out:
# 400

# %%
c.deduct_fees(1000)
# Out:
# 'We cant deduct_fees'
